# %%
import folium
import pandas as pd
import numpy as np
import json
from folium import plugins

m = folium.Map(
    location=[16, 108],
    tiles='cartodbpositron',
    zoom_start=7,
)
from folium.plugins import Geocoder

Geocoder().add_to(m)

# %%
df = pd.read_excel(r"Data\Location.xlsx")
loc_matrix = np.array(df)

# %%
#assume this path
path = ['HaNoi', 'BacNinh','HaiDuong', 'HaiPhong']
newpath = [["START",21.004355964700412, 105.84656236663436]] #add the start point
for name in path:
    for city in loc_matrix:
        if city[0] == name:
            coor = city[1].split(',')
            latitude = float(coor[0])
            longitude = float(coor[1].strip())
            newpath.append([name, latitude, longitude])
newpath.append(['ENDS',20.864056684118772, 106.71797164360206])

# %%
for city in newpath:
    if city[0] == 'START':
        pop = 'your starting point'
        col = 'lightgreen'
    elif city[0] == 'ENDS':
        pop = 'your ending point'
        col = 'red'
    else:
        pop = 'in a route'
        col = 'orange'
    folium.Marker(
    location = city[1:],
    popup = pop,
    tooltip = city[0],
    icon = folium.Icon(color = col)
    ).add_to(m)

# %%
for city in loc_matrix:
    if city[0] not in path:
        coor = city[1].split(',')
        latitude = float(coor[0])
        longitude = float(coor[1].strip())
        folium.Marker(
            location = [latitude, longitude],
            popup = 'not in any route',
            tooltip = city[0]
        ).add_to(m)

# %%
lines = []
for i in newpath:
    lines.append(tuple(i[1:]))

folium.PolyLine(lines, color = 'red', weight = 5).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb2cbbfcb3a1a06d438795e5f23387af {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb2cbbfcb3a1a06d438795e5f23387af&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bb2cbbfcb3a1a06d438795e5f23387af = L.map(
#                 &quot;map_bb2cbbfcb3a1a06d438795e5f23387af&quot;,
#                 {
#                     center: [16.0, 108.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8476e0e263a3c0062be7b1035444e1f7 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bb2cbbfcb3a1a06d438795e5f23387af);
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: false, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_bb2cbbfcb3a1a06d438795e5f23387af.setView(e.geocode.center, 11);
#             }).addTo(map_bb2cbbfcb3a1a06d438795e5f23387af);
#
#
#
#             var marker_733f548e4aba4ab38b639bfc5290d00c = L.marker(
#                 [21.004355964700412, 105.84656236663436],
#                 {}
#             ).addTo(map_bb2cbbfcb3a1a06d438795e5f23387af);
#
#
#             var icon_9ed7ecad140fa4b6ff45e64e16f9275f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgreen&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_733f548e4aba4ab38b639bfc5290d00c.setIcon(icon_9ed7ecad140fa4b6ff45e64e16f9275f);
#
#
#         var popup_66eeed448b2fa3dbe762a2277d89d5fb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5c431ad02b33a1f4e74ce249ff51a9f5 = $(`&lt;div id=&quot;html_5c431ad02b33a1f4e74ce249ff51a9f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;your starting point&lt;/div&gt;`)[0];
#                 popup_66eeed448b2fa3dbe762a2277d89d5fb.setContent(html_5c431ad02b33a1f4e74ce249ff51a9f5);
#
#
#
#         marker_733f548e4aba4ab38b639bfc5290d00c.bindPopup(popup_66eeed448b2fa3dbe762a2277d89d5fb)
#         ;
#
#
#
#
#             marker_733f548e4aba4ab38b639bfc5290d00c.bindTooltip(
#                 `&lt;div&gt;
#                      START
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2be5639e4232c1d938f9861b8874551c = L.marker(
#                 [21.02776932801737, 105.83415721961636],
#                 {}
#             ).addTo(map_bb2cbbfcb3a1a06d438795e5f23387af);
#
#
#             var icon_f32503a2ee1eda7b3aff0429c01d36ae = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2be5639e4232c1d938f9861b8874551c.setIcon(icon_f32503a2ee1eda7b3aff0429c01d36ae);
#
#
#         var popup_798ef64b1b4f76f75bfe5c4798eee6a5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5878d22d59770f6e0dd99a08e1751d22 = $(`&lt;div id=&quot;html_5878d22d59770f6e0dd99a08e1751d22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;in a route&lt;/div&gt;`)[0];
#                 popup_798ef64b1b4f76f75bfe5c4798eee6a5.setContent(html_5878d22d59770f6e0dd99a08e1751d22);
#
#
#
#         marker_2be5639e4232c1d938f9861b8874551c.bindPopup(popup_798ef64b1b4f76f75bfe5c4798eee6a5)
#         ;
#
#
#
#
#             marker_2be5639e4232c1d938f9861b8874551c.bindTooltip(
#                 `&lt;div&gt;
#                      HaNoi
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5b13aa85372130cd3eb408ff0ba9cd87 = L.marker(
#                 [21.178197360489513, 106.0710107004908],
#                 {}
#             ).addTo(map_bb2cbbfcb3a1a06d438795e5f23387af);
#
#
#             var icon_95ce2d6f530ce8a0e64bae10fd6db8fc = L.AwesomeMarkers.icon(
#                 {&quot;extraC
