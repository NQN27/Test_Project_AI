# %%
from test_class import *
import folium
from Calculate_RealDistance import transform_matrix
from Code_interface import *
from tkinter import *
import webbrowser
start,goal=Call_interface2()

answer = uniform_cost_search(encode(goal),encode(start))

answer_a = A_star_search(encode(goal), encode(start))

answer_a2 = A_star_search2(encode(goal), encode(start))

if answer == None: #if dont have any solutions
    print('no solution')
else:	
    solution = answer[0]
    path_u = answer[1]
    print('ucs minimum cost from {} to {} is {}'.format(start,goal,solution))
    print('path :')
    for i in path_u:
        print(i, end='->')
    print('UCS* nodes opened: ',expanded_nodes_U)
    print('total = ',sum(expanded_nodes_U.values()),' nodes')
    print('UCS* number of routes : ',len(expanded_routes_U))
print()
if answer_a == None: #if dont have any solutions
    print('no solution')

else:	
    solution = answer_a[0]
    path_a1 = answer_a[1]
    print('a* minimum cost from {} to {} is {}'.format(start,goal,solution))
    print('path :')
    for i in path_a1:
        print(i, end='->')        
    print('A* nodes opened: ',expanded_nodes_A1)
    print('total = ',sum(expanded_nodes_A1.values()),' nodes')
    print('A* number of routes : ',len(expanded_routes_A1))
print()

if answer_a2 == None: #if dont have any solutions
    print('no solution')

else:	
    solution = answer_a2[0]
    path_a2 = answer_a2[1]
    print('a* 2 minimum cost from {} to {} is {}'.format(start,goal,solution))
    print('path :')
    for i in path_a2:
        print(i, end='->')        
    print('A* 2 nodes opened: ',expanded_nodes_A2)
    print('total = ',sum(expanded_nodes_A2.values()),' nodes')
    print('A* 2 number of routes : ',len(expanded_routes_A2))
print()
# Out:
# ucs minimum cost from HaNoi to HoChiMinhCity is 1687.984
# path :
# HaNoi->PhuLy->NinhBinh->ThanhHoa->Vinh->HaTinh->DongHoi(QB)->DongHa->Hue->TamKy->KonTum->Pleiku->BuonMaThuot->GiaNghia(DakNong)->DongXoai(Binh Phuoc)->ThuDauMot->HoChiMinhCity->UCS* nodes opened:  {'LaiChau': 22, 'SonLa': 75, 'DienBienPhu': 33, 'HoaBinh': 97, 'LaoCai': 65, 'VietTri': 103, 'YenBai': 84, 'HaGiang': 66, 'TuyenQuang': 98, 'HaNoi': 133, 'VinhYen': 51, 'NinhBinh': 64, 'PhuLy': 97, 'ThanhHoa': 48, 'BacKan': 63, 'ThaiNguyen': 79, 'BacGiang': 93, 'BacNinh': 63, 'HungYen': 79, 'HaiDuong': 78, 'NamDinh': 47, 'ThaiBinh': 78, 'CaoBang': 44, 'LangSon': 76, 'HaLong': 45, 'HaiPhong': 46, 'Vinh': 29, 'HaTinh': 18, 'DongHoi(QB)': 18, 'DongHa': 7, 'Hue': 11, 'DaNang': 7, 'TamKy': 15, 'KonTum': 11, 'QuangNgai': 11, 'QuiNhon': 11, 'Pleiku': 15, 'TuyHoa': 15, 'BuonMaThuot': 19, 'NhaTrang': 11, 'PhanRang-ThapCham': 11, 'DaLat': 19, 'GiaNghia(DakNong)': 11, 'PhanThiet': 11, 'DongXoai(Binh Phuoc)': 23, 'BienHoa': 7, 'TayNinh': 7, 'ThuDauMot': 11, 'HoChiMinhCity': 11, 'BaRia-VungTau': 3}
# total =  2139  nodes
# UCS* number of routes :  2189
#
# a* minimum cost from HaNoi to HoChiMinhCity is 1687.984
# path :
# HaNoi->PhuLy->NinhBinh->ThanhHoa->Vinh->HaTinh->DongHoi(QB)->DongHa->Hue->TamKy->KonTum->Pleiku->BuonMaThuot->GiaNghia(DakNong)->DongXoai(Binh Phuoc)->ThuDauMot->HoChiMinhCity->A* nodes opened:  {'LaiChau': 6, 'SonLa': 55, 'DienBienPhu': 17, 'HoaBinh': 83, 'LaoCai': 36, 'VietTri': 96, 'YenBai': 56, 'HaNoi': 128, 'NinhBinh': 50, 'PhuLy': 82, 'ThanhHoa': 35, 'Vinh': 7, 'NamDinh': 33, 'TuyenQuang': 71, 'VinhYen': 47, 'HaTinh': 7, 'HungYen': 66, 'ThaiBinh': 65, 'DongHoi(QB)': 7, 'HaGiang': 37, 'BacGiang': 70, 'BacNinh': 63, 'ThaiNguyen': 54, 'HaiDuong': 55, 'HaiPhong': 23, 'DongHa': 7, 'BacKan': 37, 'Hue': 11, 'HaLong': 23, 'LangSon': 42, 'DaNang': 7, 'TamKy': 15, 'KonTum': 11, 'QuangNgai': 11, 'CaoBang': 11, 'QuiNhon': 11, 'Pleiku': 15, 'TuyHoa': 15, 'BuonMaThuot': 15, 'NhaTrang': 11, 'DaLat': 15, 'GiaNghia(DakNong)': 7, 'DongXoai(Binh Phuoc)': 7, 'PhanRang-ThapCham': 3, 'BienHoa': 7, 'PhanThiet': 7, 'TayNinh': 7, 'ThuDauMot': 3, 'HoChiMinhCity': 3}
# total =  1550  nodes
# A* number of routes :  1599
#
# a* 2 minimum cost from HaNoi to HoChiMinhCity is 1687.984
# path :
# HaNoi->PhuLy->NinhBinh->ThanhHoa->Vinh->HaTinh->DongHoi(QB)->DongHa->Hue->TamKy->KonTum->Pleiku->BuonMaThuot->GiaNghia(DakNong)->DongXoai(Binh Phuoc)->ThuDauMot->HoChiMinhCity->A* 2 nodes opened:  {'LaiChau': 2, 'SonLa': 16, 'DienBienPhu': 13, 'HoaBinh': 49, 'LaoCai': 13, 'VietTri': 31, 'YenBai': 24, 'HaNoi': 17, 'NinhBinh': 9, 'PhuLy': 20, 'ThanhHoa': 9, 'Vinh': 7, 'HaTinh': 7, 'DongHoi(QB)': 7, 'DongHa': 7, 'Hue': 7, 'DaNang': 7, 'TamKy': 7, 'KonTum': 7, 'QuangNgai': 7, 'Pleiku': 7, 'BuonMaThuot': 7, 'QuiNhon': 3, 'TuyHoa': 7, 'DaLat': 11, 'GiaNghia(DakNong)': 7, 'NhaTrang': 3, 'DongXoai(Binh Phuoc)': 7, 'BienHoa': 7, 'PhanThiet': 3, 'TayNinh': 7, 'ThuDauMot': 3, 'HoChiMinhCity': 3, 'BacGiang': 16, 'BacNinh': 15, 'HungYen': 19, 'ThaiNguyen': 14, 'VinhYen': 25, 'TuyenQuang': 10, 'HaiDuong': 0, 'HaiPhong': 0, 'ThaiBinh': 3, 'NamDinh': 5}
# total =  448  nodes
# A* 2 number of routes :  491

# %%
dl = pd.read_excel(r"Location.xlsx")
loc_matrix = np.array(dl)

START = ["START", float(transform_matrix(start)[0]), float(transform_matrix(start)[1])]
END = ['ENDS', float(transform_matrix(goal)[0]), float(transform_matrix(goal)[1])]

# %%
m = folium.Map(
location=[16, 108],
tiles='cartodbpositron',
zoom_start=7,
)

from folium.plugins import Geocoder
Geocoder().add_to(m)

# %%
def draw_line(city, l, loc_matrix, col):
    path = city.path
    newpath = []
    for name in path:
        for city in loc_matrix:
            if city[0] == name:
                coor = city[1].split(',')
                latitude = float(coor[0])
                longitude = float(coor[1].strip())
                newpath.append([name, latitude, longitude])
    lines = []
    for i in newpath:
        lines.append(tuple(i[1:]))
    folium.PolyLine(lines, color = col, weight = 2).add_to(l)

# %%
optimal_layer = folium.FeatureGroup(name = "optimal layer by ucs/a*")
ucs_layer = folium.FeatureGroup(name = "ucs layer")
a_star_layer1 = folium.FeatureGroup(name = "a* layer with coef = 1")
a_star_layer2 = folium.FeatureGroup(name = "a* layer with coef = 2")

optimal_path = path_u

newpath = [START]
for name in optimal_path:
    for city in loc_matrix:
        if city[0] == name:
            coor = city[1].split(',')
            latitude = float(coor[0])
            longitude = float(coor[1].strip())
            newpath.append([name, latitude, longitude])

newpath.append(END)

for city in newpath:
    if city[0] == 'START':
        pop = 'your starting point'
        col = 'lightgreen'
    elif city[0] == 'ENDS':
        pop = 'your ending point'
        col = 'red'
    else:
        pop = 'in a route'
        col = 'orange'
    folium.Marker(
    location = city[1:],
    popup = pop,
    tooltip = city[0],
    icon = folium.Icon(color = col)
    ).add_to(optimal_layer)

for city in loc_matrix:
    if city[0] not in optimal_path:
        coor = city[1].split(',')
        latitude = float(coor[0])
        longitude = float(coor[1].strip())
        folium.Marker(
            location = [latitude, longitude],
            popup = 'not in any route',
            tooltip = city[0]
        ).add_to(optimal_layer)
    if city[0] in expanded_nodes_U:
        coor = city[1].split(',')
        latitude = float(coor[0])
        longitude = float(coor[1].strip())
        if expanded_nodes_U[city[0]] <= 10:
            col = 'lightgreen'
        elif expanded_nodes_U[city[0]] > 10 and expanded_nodes_U[city[0]] <= 50:
            col = 'orange'
        else:
            col = 'red'
        folium.Marker(
            location = [latitude, longitude],
            popup = 'appear {} times'.format(expanded_nodes_U[city[0]]),
            tooltip = city[0],
            icon = folium.Icon(color = col)
        ).add_to(ucs_layer)
    else: 
        coor = city[1].split(',')
        latitude = float(coor[0])
        longitude = float(coor[1].strip())
        folium.Marker(
            location = [latitude, longitude],
            popup = "haven't expanded",
            tooltip = city[0]
        ).add_to(ucs_layer)

    if city[0] in expanded_nodes_A1:
        coor = city[1].split(',')
        latitude = float(coor[0])
        longitude = float(coor[1].strip())
        if expanded_nodes_A1[city[0]] <= 10:
            col = 'lightgreen'
        elif expanded_nodes_A1[city[0]] > 10 and expanded_nodes_A1[city[0]] <= 50:
            col = 'orange'
        else:
            col = 'red'
        folium.Marker(
            location = [latitude, longitude],
            popup = 'appear {} times'.format(expanded_nodes_A1[city[0]]),
            tooltip = city[0],
            icon = folium.Icon(color = col)
        ).add_to(a_star_layer1)
    else: 
        coor = city[1].split(',')
        latitude = float(coor[0])
        longitude = float(coor[1].strip())
        folium.Marker(
            location = [latitude, longitude],
            popup = "haven't expanded",
            tooltip = city[0]
        ).add_to(a_star_layer1)
    
    if city[0] in expanded_nodes_A2:
        coor = city[1].split(',')
        latitude = float(coor[0])
        longitude = float(coor[1].strip())
        if expanded_nodes_A2[city[0]] <= 10:
            col = 'lightgreen'
        elif expanded_nodes_A2[city[0]] > 10 and expanded_nodes_A2[city[0]] <= 50:
            col = 'orange'
        else:
            col = 'red'
        folium.Marker(
            location = [latitude, longitude],
            popup = 'appear {} times'.format(expanded_nodes_A2[city[0]]),
            tooltip = city[0],
            icon = folium.Icon(color = col)
        ).add_to(a_star_layer2)
    else: 
        coor = city[1].split(',')
        latitude = float(coor[0])
        longitude = float(coor[1].strip())
        folium.Marker(
            location = [latitude, longitude],
            popup = "haven't expanded",
            tooltip = city[0]
        ).add_to(a_star_layer2)
    
lines = []
for i in newpath:
    lines.append(tuple(i[1:]))
folium.PolyLine(lines, color = 'red', weight = 5).add_to(optimal_layer)

for city in expanded_routes_U:
    draw_line(city, ucs_layer, loc_matrix, 'pink')
    
for city in expanded_routes_A1:
    draw_line(city, a_star_layer1, loc_matrix, 'purple')
    
for city in expanded_routes_A2:
    draw_line(city, a_star_layer2, loc_matrix, 'blue')

optimal_layer.add_to(m)
ucs_layer.add_to(m)
a_star_layer1.add_to(m)
a_star_layer2.add_to(m)

folium.LayerControl().add_to(m)

m

show_map(m)

# %%
'''
    if city[0] in expanded_nodes_U:
        coor = city[1].split(',')
        latitude = float(coor[0])
        longitude = float(coor[1].strip())
        if expanded_nodes_U[city[0]] <= 3:
            col = 'lightgreen'
        elif expanded_nodes_U[city[0]] > 3 and expanded_nodes_U[city[0]] <= 5:
            col = 'orange'
        else:
            col = 'red'
        folium.Marker(
            location = [latitude, longitude],
            popup = 'appear {} times'.format(expanded_nodes_U[city[0]]),
            tooltip = city[0],
            icon = folium.Icon(color = col)
        ).add_to(ucs_layer)
    else: 
        coor = city[1].split(',')
        latitude = float(coor[0])
        longitude = float(coor[1].strip())
        folium.Marker(
            location = [latitude, longitude],
            popup = "haven't expanded",
            tooltip = city[0]
        ).add_to(ucs_layer)

    if city[0] in expanded_nodes_A1:
        coor = city[1].split(',')
        latitude = float(coor[0])
        longitude = float(coor[1].strip())
        if expanded_nodes_A1[city[0]] <= 3:
            col = 'lightgreen'
        elif expanded_nodes_A1[city[0]] > 3 and expanded_nodes_A1[city[0]] <= 5:
            col = 'orange'
        else:
            col = 'red'
        folium.Marker(
            location = [latitude, longitude],
            popup = 'appear {} times'.format(expanded_nodes_A1[city[0]]),
            tooltip = city[0],
            icon = folium.Icon(color = col)
        ).add_to(a_star_layer1)
    else: 
        coor = city[1].split(',')
        latitude = float(coor[0])
        longitude = float(coor[1].strip())
        folium.Marker(
            location = [latitude, longitude],
            popup = "haven't expanded",
            tooltip = city[0]
        ).add_to(a_star_layer1)
    
    if city[0] in expanded_nodes_A2:
        coor = city[1].split(',')
        latitude = float(coor[0])
        longitude = float(coor[1].strip())
        if expanded_nodes_A2[city[0]] <= 3:
            col = 'lightgreen'
        elif expanded_nodes_A2[city[0]] > 3 and expanded_nodes_A2[city[0]] <= 5:
            col = 'orange'
        else:
            col = 'red'
        folium.Marker(
            location = [latitude, longitude],
            popup = 'appear {} times'.format(expanded_nodes_A2[city[0]]),
            tooltip = city[0],
            icon = folium.Icon(color = col)
        ).add_to(a_star_layer1)
    else: 
        coor = city[1].split(',')
        latitude = float(coor[0])
        longitude = float(coor[1].strip())
        folium.Marker(
            location = [latitude, longitude],
            popup = "haven't expanded",
            tooltip = city[0]
        ).add_to(a_star_layer2)
    
lines = []
for i in newpath:
    lines.append(tuple(i[1:]))
folium.PolyLine(lines, color = 'red', weight = 5).add_to(optimal_layer)

for city in expanded_routes_U:
    draw_line(city, ucs_layer, loc_matrix)

for city in expanded_routes_A1:
    draw_line(city, a_star_layer1, loc_matrix)

for city in expanded_routes_A2:
    draw_line(city, a_star_layer2, loc_matrix)

'''
# Out:
# '\n    if city[0] in expanded_nodes_U:\n        coor = city[1].split(\',\')\n        latitude = float(coor[0])\n        longitude = float(coor[1].strip())\n        if expanded_nodes_U[city[0]] <= 3:\n            col = \'lightgreen\'\n        elif expanded_nodes_U[city[0]] > 3 and expanded_nodes_U[city[0]] <= 5:\n            col = \'orange\'\n        else:\n            col = \'red\'\n        folium.Marker(\n            location = [latitude, longitude],\n            popup = \'appear {} times\'.format(expanded_nodes_U[city[0]]),\n            tooltip = city[0],\n            icon = folium.Icon(color = col)\n        ).add_to(ucs_layer)\n    else: \n        coor = city[1].split(\',\')\n        latitude = float(coor[0])\n        longitude = float(coor[1].strip())\n        folium.Marker(\n            location = [latitude, longitude],\n            popup = "haven\'t expanded",\n            tooltip = city[0]\n        ).add_to(ucs_layer)\n\n    if city[0] in expanded_nodes_A1:\n        coor = city[1].split(\',\')\n        latitude = float(coor[0])\n        longitude = float(coor[1].strip())\n        if expanded_nodes_A1[city[0]] <= 3:\n            col = \'lightgreen\'\n        elif expanded_nodes_A1[city[0]] > 3 and expanded_nodes_A1[city[0]] <= 5:\n            col = \'orange\'\n        else:\n            col = \'red\'\n        folium.Marker(\n            location = [latitude, longitude],\n            popup = \'appear {} times\'.format(expanded_nodes_A1[city[0]]),\n            tooltip = city[0],\n            icon = folium.Icon(color = col)\n        ).add_to(a_star_layer1)\n    else: \n        coor = city[1].split(\',\')\n        latitude = float(coor[0])\n        longitude = float(coor[1].strip())\n        folium.Marker(\n            location = [latitude, longitude],\n            popup = "haven\'t expanded",\n            tooltip = city[0]\n        ).add_to(a_star_layer1)\n    \n    if city[0] in expanded_nodes_A2:\n        coor = city[1].split(\',\')\n        latitude = float(coor[0])\n        longitude = float(coor[1].strip())\n        if expanded_nodes_A2[city[0]] <= 3:\n            col = \'lightgreen\'\n        elif expanded_nodes_A2[city[0]] > 3 and expanded_nodes_A2[city[0]] <= 5:\n            col = \'orange\'\n        else:\n            col = \'red\'\n        folium.Marker(\n            location = [latitude, longitude],\n            popup = \'appear {} times\'.format(expanded_nodes_A2[city[0]]),\n            tooltip = city[0],\n            icon = folium.Icon(color = col)\n        ).add_to(a_star_layer1)\n    else: \n        coor = city[1].split(\',\')\n        latitude = float(coor[0])\n        longitude = float(coor[1].strip())\n        folium.Marker(\n            location = [latitude, longitude],\n            popup = "haven\'t expanded",\n            tooltip = city[0]\n        ).add_to(a_star_layer2)\n    \nlines = []\nfor i in newpath:\n    lines.append(tuple(i[1:]))\nfolium.PolyLine(lines, color = \'red\', weight = 5).add_to(optimal_layer)\n\nfor city in expanded_routes_U:\n    draw_line(city, ucs_layer, loc_matrix)\n\nfor city in expanded_routes_A1:\n    draw_line(city, a_star_layer1, loc_matrix)\n\nfor city in expanded_routes_A2:\n    draw_line(city, a_star_layer2, loc_matrix)\n\n'
