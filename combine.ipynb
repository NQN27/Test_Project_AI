# %%
from test_class import *
from map_folium import *

start = 'HaNoi'
goal = 'DienBienPhu'

answer = uniform_cost_search(encode(goal),encode(start))

answer_a = A_star_search(encode(goal), encode(start))

answer_a2 = A_star_search2(encode(goal), encode(start))


if answer == None: #if dont have any solutions
    print('no solution')
else:	
    solution = answer[0]
    path_u = answer[1]
    print('ucs minimum cost from {} to {} is {}'.format(start,goal,solution))
    print('path :')
    for i in path_u:
        print(i, end='->')
    print('UCS* nodes opened: ',expanded_nodes_U)
    print('total = ',sum(expanded_nodes_U.values()),' nodes')
    print('UCS* number of routes : ',len(expanded_routes_U))
print()
if answer_a == None: #if dont have any solutions
    print('no solution')

else:	
    solution = answer_a[0]
    path_a1 = answer_a[1]
    print('a* minimum cost from {} to {} is {}'.format(start,goal,solution))
    print('path :')
    for i in path_a1:
        print(i, end='->')        
    print('A* nodes opened: ',expanded_nodes_A1)
    print('total = ',sum(expanded_nodes_A1.values()),' nodes')
    print('A* number of routes : ',len(expanded_routes_A1))
print()

if answer_a2 == None: #if dont have any solutions
    print('no solution')

else:	
    solution = answer_a2[0]
    path_a2 = answer_a2[1]
    print('a* 2 minimum cost from {} to {} is {}'.format(start,goal,solution))
    print('path :')
    for i in path_a2:
        print(i, end='->')        
    print('A* 2 nodes opened: ',expanded_nodes_A2)
    print('total = ',sum(expanded_nodes_A2.values()),' nodes')
    print('A* 2 number of routes : ',len(expanded_routes_A2))
print()
# Out:
# ucs minimum cost from HaNoi to DienBienPhu is 456.05
# path :
# HaNoi->HoaBinh->SonLa->DienBienPhu->UCS* nodes opened:  {'BacGiang': 6, 'BacNinh': 4, 'HoaBinh': 6, 'HungYen': 5, 'PhuLy': 6, 'ThaiNguyen': 5, 'VietTri': 6, 'VinhYen': 3, 'HaiDuong': 5, 'HaNoi': 8, 'TuyenQuang': 6, 'HaLong': 3, 'LangSon': 5, 'ThaiBinh': 5, 'NamDinh': 3, 'NinhBinh': 4, 'SonLa': 4, 'ThanhHoa': 3, 'BacKan': 4, 'YenBai': 5, 'HaiPhong': 3, 'HaGiang': 4, 'CaoBang': 3, 'LaoCai': 4, 'Vinh': 2, 'DienBienPhu': 2, 'HaTinh': 1, 'LaiChau': 1, 'DongHoi(QB)': 1}
# total =  117  nodes
# UCS* number of routes :  117
#
# a* minimum cost from HaNoi to DienBienPhu is 456.05
# path :
# HaNoi->HoaBinh->SonLa->DienBienPhu->A* nodes opened:  {'BacGiang': 4, 'BacNinh': 4, 'HoaBinh': 5, 'HungYen': 4, 'PhuLy': 5, 'ThaiNguyen': 3, 'VietTri': 6, 'VinhYen': 3, 'HaNoi': 8, 'TuyenQuang': 4, 'NinhBinh': 3, 'SonLa': 3, 'ThanhHoa': 2, 'YenBai': 3, 'HaiDuong': 3, 'HaGiang': 2, 'LaoCai': 2, 'BacKan': 2, 'LangSon': 2, 'NamDinh': 2, 'ThaiBinh': 4, 'HaLong': 1, 'DienBienPhu': 1, 'HaiPhong': 1}
# total =  77  nodes
# A* number of routes :  77
#
# a* 2 minimum cost from HaNoi to DienBienPhu is 460.06
# path :
# HaNoi->VietTri->SonLa->DienBienPhu->A* 2 nodes opened:  {'BacGiang': 1, 'BacNinh': 1, 'HoaBinh': 3, 'HungYen': 1, 'PhuLy': 1, 'ThaiNguyen': 1, 'VietTri': 2, 'VinhYen': 2, 'HaNoi': 1, 'SonLa': 1, 'TuyenQuang': 1, 'YenBai': 2, 'DienBienPhu': 1, 'LaoCai': 1}
# total =  19  nodes
# A* 2 number of routes :  19

# %%
dl = pd.read_excel('/Users/luong/OneDrive - Hanoi University of Science and Technology/project/Location.xlsx')
loc_matrix = np.array(dl)

START = ["START", 21.004355964700412, 105.84656236663436]
END = ['ENDS', 21.38860789042951, 103.02419543965866]

# %%
draw_map(START, END, path_u, loc_matrix, expanded_nodes_U, expanded_routes_U,expanded_nodes_A1, expanded_routes_A1,expanded_nodes_A2, expanded_routes_A2)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_38a7b08b8bb1a7704adc4de7188731b2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_38a7b08b8bb1a7704adc4de7188731b2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_38a7b08b8bb1a7704adc4de7188731b2 = L.map(
#                 &quot;map_38a7b08b8bb1a7704adc4de7188731b2&quot;,
#                 {
#                     center: [16.0, 108.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3e9cafe3711874f83e2cedc95589d3b2 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_38a7b08b8bb1a7704adc4de7188731b2);
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: false, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_38a7b08b8bb1a7704adc4de7188731b2.setView(e.geocode.center, 11);
#             }).addTo(map_38a7b08b8bb1a7704adc4de7188731b2);
#
#
#
#             var feature_group_dfcba8c98f71a5f702fff7d02fc65766 = L.featureGroup(
#                 {}
#             ).addTo(map_38a7b08b8bb1a7704adc4de7188731b2);
#
#
#             var marker_2d74d7341ff27528af5e45994733fb8a = L.marker(
#                 [21.004355964700412, 105.84656236663436],
#                 {}
#             ).addTo(feature_group_dfcba8c98f71a5f702fff7d02fc65766);
#
#
#             var icon_32dc21254974b70192986f81857f37b7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgreen&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2d74d7341ff27528af5e45994733fb8a.setIcon(icon_32dc21254974b70192986f81857f37b7);
#
#
#         var popup_238af011900d8f2566c7e6f913451c25 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_67eb1657f855ade4ec386f163bd97b16 = $(`&lt;div id=&quot;html_67eb1657f855ade4ec386f163bd97b16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;your starting point&lt;/div&gt;`)[0];
#                 popup_238af011900d8f2566c7e6f913451c25.setContent(html_67eb1657f855ade4ec386f163bd97b16);
#
#
#
#         marker_2d74d7341ff27528af5e45994733fb8a.bindPopup(popup_238af011900d8f2566c7e6f913451c25)
#         ;
#
#
#
#
#             marker_2d74d7341ff27528af5e45994733fb8a.bindTooltip(
#                 `&lt;div&gt;
#                      START
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2584597c201282477d93758a43326789 = L.marker(
#                 [21.02776932801737, 105.83415721961636],
#                 {}
#             ).addTo(feature_group_dfcba8c98f71a5f702fff7d02fc65766);
#
#
#             var icon_6ae425ae0bd8aeedf1c983bcbd9318dc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2584597c201282477d93758a43326789.setIcon(icon_6ae425ae0bd8aeedf1c983bcbd9318dc);
#
#
#         var popup_e89b47429960ee46699ce5ad07a69df9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_25da8a976f56fafd1a58e4d0c0711b5d = $(`&lt;div id=&quot;html_25da8a976f56fafd1a58e4d0c0711b5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;in a route&lt;/div&gt;`)[0];
#                 popup_e89b47429960ee46699ce5ad07a69df9.setContent(html_25da8a976f56fafd1a58e4d0c0711b5d);
#
#
#
#         marker_2584597c201282477d93758a43326789.bindPopup(popup_e89b47429960ee46699ce5ad07a69df9)
#         ;
#
#
#
#
#             marker_2584597c201282477d93758a43326789.bindTooltip(
#                 `&lt;div&gt;
#                      HaNoi
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_980f609dfabd92942ab28d78d145f94e = L.marker(
#                 [20.827512714577754, 105.33909287800593],
